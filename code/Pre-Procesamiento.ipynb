# %% [markdown]
# ## Pre-Procesamiento del conjunto de datos

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %%
Frvids = pd.read_csv('FRvideos_cc50_202101.csv')

# %%
Frvids.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
Frvids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40724 entries, 0 to 40723
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40724 non-null  object
#  1   trending_date           40724 non-null  object
#  2   title                   40724 non-null  object
#  3   channel_title           40724 non-null  object
#  4   category_id             40724 non-null  int64
#  5   publish_time            40724 non-null  object
#  6   tags                    40724 non-null  object
#  7   views                   40724 non-null  int64
#  8   likes                   40724 non-null  int64
#  9   dislikes                40724 non-null  int64
#  10  comment_count           40724 non-null  int64
#  11  thumbnail_link          40724 non-null  object
#  12  comments_disabled       40724 non-null  bool
#  13  ratings_disabled        40724 non-null  bool
# ...

# %%
Frvids.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count  \
# count  40724.000000  4.072400e+04  4.072400e+04  4.072400e+04   4.072400e+04
# mean      20.123809  4.199219e+05  1.738886e+04  8.149624e+02   1.832453e+03
# std        6.984422  1.772130e+06  8.720509e+04  1.139219e+04   1.404321e+04
# min        1.000000  2.230000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  1.697450e+04  3.380000e+02  1.800000e+01   5.600000e+01
# 50%       23.000000  7.372100e+04  1.892500e+03  8.300000e+01   2.350000e+02
# 75%       24.000000  2.708088e+05  7.969500e+03  3.350000e+02   8.410000e+02
# max       44.000000  1.009116e+08  4.750254e+06  1.353661e+06   1.040912e+06
#
#                 lat           lon
# count  40724.000000  40724.000000
# mean      36.986535     -2.314779
# std       19.889834     25.443453
# min      -21.033511    -61.532999
# 25%       42.699989     -0.530030
# 50%       45.899975      2.666648
# ...

# %% [markdown]
# ## Extraccion de datos de Json

# %%
with open("FR_category_id.json") as file:
    jdata = json.load(file)

# %%
ids = [jdata['items'][i]['id'] for i in range(len(jdata['items']))]
titles = [jdata['items'][i]['snippet']['title'] for i in range(len(jdata['items']))]
ids = np.array(ids)
ids = list(map(int, ids))

# %%
category = {}
for key in ids:
    for value in titles:
        category[key] = value
        titles.remove(value)
        break 
category
# Out:
# {1: 'Film & Animation',
#  2: 'Autos & Vehicles',
#  10: 'Music',
#  15: 'Pets & Animals',
#  17: 'Sports',
#  18: 'Short Movies',
#  19: 'Travel & Events',
#  20: 'Gaming',
#  21: 'Videoblogging',
#  22: 'People & Blogs',
#  23: 'Comedy',
#  24: 'Entertainment',
#  25: 'News & Politics',
#  26: 'Howto & Style',
#  27: 'Education',
#  28: 'Science & Technology',
#  30: 'Movies',
#  31: 'Anime/Animation',
#  32: 'Action/Adventure',
#  33: 'Classics',
#  34: 'Comedy',
#  35: 'Documentary',
#  36: 'Drama',
#  37: 'Family',
#  38: 'Foreign',
#  39: 'Horror',
#  40: 'Sci-Fi/Fantasy',
#  41: 'Thriller',
#  42: 'Shorts',
#  43: 'Shows',
#  44: 'Trailers'}

# %%
df_ctitles = []
for i in range(len(Frvids)):
    if Frvids['category_id'][i] in ids:
        for j in ids:
            if Frvids['category_id'][i] == j:
                df_ctitles.append(category[j])
                continue
    else:
        df_ctitles.append('')
print(len(df_ctitles))
# Out:
# 40724

# %%
Frvids['category_title'] = np.array(df_ctitles)
Frvids['category_title'].replace('',np.NaN)
# Out:
# 0           Entertainment
# 1           Entertainment
# 2                  Comedy
# 3                  Gaming
# 4                  Sports
#                ...
# 40719    Film & Animation
# 40720     News & Politics
# 40721      People & Blogs
# 40722    Film & Animation
# 40723       Entertainment
# Name: category_title, Length: 40724, dtype: object

# %%
Frvids.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %% [markdown]
# ## Identificación de valores NA en el dataframe

# %%
print(Frvids.isna().sum())
sns.heatmap(Frvids.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               2912
# state                        0
# lat                          0
# lon                          0
# geometry                     0
# category_title               0
# dtype: int64
# <AxesSubplot:>

# %% [markdown]
# La columna description es la unica con valores NA. Y mediante el heatmap podemos ver que es una cantidad minima de filas que se ven afectadas (2912 de 40724 filas). Por lo tanto se ha decidido eliminar las filas que contienen estos valores vacios.

# %%
FrvidsClean = Frvids[Frvids['description'].notna()]

# %%
print(FrvidsClean.isna().sum())
sns.heatmap(FrvidsClean.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# video_id                  0
# trending_date             0
# title                     0
# channel_title             0
# category_id               0
# publish_time              0
# tags                      0
# views                     0
# likes                     0
# dislikes                  0
# comment_count             0
# thumbnail_link            0
# comments_disabled         0
# ratings_disabled          0
# video_error_or_removed    0
# description               0
# state                     0
# lat                       0
# lon                       0
# geometry                  0
# category_title            0
# dtype: int64
# <AxesSubplot:>

# %%
FrvidsClean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37812 entries, 0 to 40722
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                37812 non-null  object
#  1   trending_date           37812 non-null  object
#  2   title                   37812 non-null  object
#  3   channel_title           37812 non-null  object
#  4   category_id             37812 non-null  int64
#  5   publish_time            37812 non-null  object
#  6   tags                    37812 non-null  object
#  7   views                   37812 non-null  int64
#  8   likes                   37812 non-null  int64
#  9   dislikes                37812 non-null  int64
#  10  comment_count           37812 non-null  int64
#  11  thumbnail_link          37812 non-null  object
#  12  comments_disabled       37812 non-null  bool
#  13  ratings_disabled        37812 non-null  bool
# ...

# %% [markdown]
# ## Exportacion de dataframe limpio

# %%
FrvidsClean.to_csv('FRvideos_Clean.csv')
